# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.DataFrame({
    "time": pd.date_range("2025-01-01", periods=5, freq="H"),
    "price": np.random.rand(5) * 100
})
data.plot(x="time", y="price", marker="o")
plt.show()
# Out:
# /var/folders/1k/3np8cs093slgrwgq0rzzt9_40000gp/T/ipykernel_76249/1396099863.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   "time": pd.date_range("2025-01-01", periods=5, freq="H"),

# %%
#test
